# %% [markdown]
# # Futures long-only performance summary
#
# This notebook summarises long-only performance statistics for major futures contracts provided by various data sources. Daily returns are computed by rolling the front contract before either the first notice day or the last trade day to avoid deliveries. Concretely, a daily return on a given day is written as follows:
#
# $$
# r_{t, i} = \frac{F_{t, i} - F_{t-1, t}}{F_{rolldate, i}}
# $$
#
# where $F_{t, i}$ is the futures price at time $t$ for an instrument $i$, $F_{rolldate, i}$ is the futures price when we roll into the contract. All functionalities as well as underlying data are provided by a private library `vivace`.

# %%
from datetime import datetime
import logging
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import pytz
import matplotlib.pyplot as plt
plt.style.use('bmh')

from vivace.backtest.contract import all_futures_lo_map
from vivace.backtest.engine import BacktestEngine
from vivace.backtest.stats import Performance, PerfStats
from vivace.enums import Strategy

# %% [markdown]
# `all_futures_lo_map` contains the list of all available futures contracts for long-only calculation.

# %%
all_futures_lo_map
# Out:
# ticker
# AC            MSCI World
# AD     Australian Dollar
# AE                   AEX
# AP               SPI 200
# B8     CZCE Ferrosilicon
#              ...
# YQ       DCE Coking Coal
# YY          DCE Iron Ore
# Z               FTSE 100
# ZB    New Zealand Dollar
# ZO                  Oats
# Name: name, Length: 168, dtype: str

# %% [markdown]
# Without any signals, `BacktestEngine` calculates simple long-only strategies by default. `Performance` computes typical performance metrics such as Sharpe ratio.

# %%
results = []

for ticker, name in all_futures_lo_map.items():
    engine = BacktestEngine(
        instrument=ticker,
        strategy=Strategy.DELTA_ONE.value,
        log_level=logging.WARNING,
    )
    engine.run()
    equity_curve = engine.calculate_equity_curve(calculate_net=False)
    stats = Performance(equity_curve).summary().squeeze()
    
    results.append([
        name,
        equity_curve.index[0].strftime('%d-%b-%Y'),
        equity_curve.index[-1].strftime('%d-%b-%Y'),
        stats[PerfStats.CAGR.value],
        stats[PerfStats.ANN_VOL.value],
        stats[PerfStats.SHARPE.value],
        stats[PerfStats.SKEWNESS.value],
    ])
    
result = pd.DataFrame(results, columns=[
    'contract', 'start_end', 'end_date',
    PerfStats.CAGR.value, 
    PerfStats.ANN_VOL.value,
    PerfStats.SHARPE.value,
    PerfStats.SKEWNESS.value,
]).set_index('contract')

# %%
result.shape
# Out:
# (168, 6)

# %% [markdown]
# # Performance summary
#
# This table displays contract information such as the contract name as well as performance statistics. Bar charts are superimposed for annualised returns and Sharpe ratios based on its value.   Statistics are in contracts' local currencies.
# Note that some start dates do not match the exact inception of the futures contract because of limited data availability.

# %%
(result
 .style.format({
        PerfStats.CAGR.value: "{:.1%}",
        PerfStats.ANN_VOL.value: "{:.1%}",
        PerfStats.SHARPE.value: "{:.2f}",
        PerfStats.SKEWNESS.value: "{:.2f}",
    })
 .bar(subset=PerfStats.CAGR.value)
 .bar(subset=PerfStats.SHARPE.value))
# Out:
# <style type="text/css">
# #T_c83a6_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 86.5%, transparent 86.5%);
# }
# #T_c83a6_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 78.3%, transparent 78.3%);
# }
# #T_c83a6_row1_col2, #T_c83a6_row33_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 80.8%, transparent 80.8%);
# }
# #T_c83a6_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 61.6%, transparent 61.6%);
# }
# #T_c83a6_row2_col2, #T_c83a6_row150_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 85.1%, transparent 85.1%);
# }
# #T_c83a6_row2_col4, #T_c83a6_row55_col4, #T_c83a6_row57_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 69.6%, transparent 69.6%);
# }
# #T_c83a6_row3_col2, #T_c83a6_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 83.1%, transparent 83.1%);
# }
# #T_c83a6_row3_col4, #T_c83a6_row97_col4, #T_c83a6_row105_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 66.6%, transparent 66.6%);
# }
# #T_c83a6_row4_col2, #T_c83a6_row42_col2, #T_c83a6_row93_col2, #T_c83a6_row99_col2, #T_c83a6_row162_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 79.5%, transparent 79.5%);
# }
# #T_c83a6_row4_col4, #T_c83a6_row93_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 54.8%, transparent 54.8%);
# }
# #T_c83a6_row5_col2, #T_c83a6_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 84.7%, transparent 84.7%);
# }
# #T_c83a6_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 67.6%, transparent 67.6%);
# }
# #T_c83a6_row6_col2, #T_c83a6_row118_col2, #T_c83a6_row167_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 81.4%, transparent 81.4%);
# }
# #T_c83a6_row6_col4, #T_c83a6_row94_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 58.6%, transparent 58.6%);
# }
# #T_c83a6_row7_col2, #T_c83a6_row26_col2, #T_c83a6_row145_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_c83a6_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 54.7%, transparent 54.7%);
# }
# #T_c83a6_row8_col2, #T_c83a6_row32_col2, #T_c83a6_row50_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 82.2%, transparent 82.2%);
# }
# #T_c83a6_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 64.3%, transparent 64.3%);
# }
# #T_c83a6_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 93.3%, transparent 93.3%);
# }
# #T_c83a6_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 65.4%, transparent 65.4%);
# }
# #T_c83a6_row10_col2, #T_c83a6_row87_col2, #T_c83a6_row154_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.9%, #d65f5f 78.9%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_c83a6_row10_col4, #T_c83a6_row139_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.6%, #d65f5f 53.6%, #d65f5f 54.0%, transparent 54.0%);
# }
# #T_c83a6_row11_col2, #T_c83a6_row146_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 77.4%, #d65f5f 77.4%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_c83a6_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.8%, #d65f5f 49.8%, #d65f5f 54.0%, transparent 54.0%);
# }
# #T_c83a6_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.1%, #d65f5f 78.1%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_c83a6_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 52.2%, #d65f5f 52.2%, #d65f5f 54.0%, transparent 54.0%);
# }
# #T_c83a6_row13_col2, #T_c83a6_row91_col2, #T_c83a6_row139_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.0%, #d65f5f 79.0%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_c83a6_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 52.6%, #d65f5f 52.6%, #d65f5f 54.0%, transparent 54.0%);
# }
# #T_c83a6_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 63.6%, transparent 63.6%);
# }
# #T_c83a6_row15_col2, #T_c83a6_row59_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 80.9%, transparent 80.9%);
# }
# #T_c83a6_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 73.3%, transparent 73.3%);
# }
# #T_c83a6_row16_col2, #T_c83a6_row72_col2, #T_c83a6_row165_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 82.8%, transparent 82.8%);
# }
# #T_c83a6_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 76.0%, transparent 76.0%);
# }
# #T_c83a6_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 81.7%, transparent 81.7%);
# }
# #T_c83a6_row17_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 57.6%, transparent 57.6%);
# }
# #T_c83a6_row18_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 62.3%, transparent 62.3%);
# }
# #T_c83a6_row19_col2, #T_c83a6_row44_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 81.2%, transparent 81.2%);
# }
# #T_c83a6_row19_col4, #T_c83a6_row46_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 77.0%, transparent 77.0%);
# }
# #T_c83a6_row20_col2, #T_c83a6_row39_col2, #T_c83a6_row65_col2, #T_c83a6_row111_col2, #T_c83a6_row113_col2, #T_c83a6_row114_col2, #T_c83a6_row159_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_c83a6_row20_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 54.0%, transparent 54.0%);
# }
# #T_c83a6_row21_col2, #T_c83a6_row120_col2, #T_c83a6_row132_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 85.2%, transparent 85.2%);
# }
# #T_c83a6_row21_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 69.8%, transparent 69.8%);
# }
# #T_c83a6_row22_col2, #T_c83a6_row62_col2, #T_c83a6_row123_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 80.7%, transparent 80.7%);
# }
# #T_c83a6_row22_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 62.2%, transparent 62.2%);
# }
# #T_c83a6_row23_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 85.3%, transparent 85.3%);
# }
# #T_c83a6_row23_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 54.0%, #d65f5f 54.0%, #d65f5f 71.9%, transparent 71.9%);
# }
# #T_c83a6_row24_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.0%, #d65f5f 78.0%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_c83a6_row24_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.7%, #d65f5f 46.7%, #d65f5f 54.0%, transparent 54.0%);
# }
# #T_c83a6_row25_col2, #T_c83a6_row79_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.5%, #d65f5f 78.5%, #d65f5f 79.1%, transparent 7

# %%
fig, ax = plt.subplots(figsize=(8, 20))
ax.set_title("Long-only Sharpe ratio")
ax.set_ylabel("Sharpe ratio")
result[PerfStats.SHARPE.value].loc[::-1].plot(kind="barh", ax=ax, grid=True);  # reverse the plot order
ax.axvline(0, lw=1);

# %% [markdown]
# # Plot cumulative return series
#
# Here only the E-mini S&P 500 futures is shown as an example.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
engine = BacktestEngine(
    instrument='ES',
    strategy=Strategy.DELTA_ONE.value,
    log_level=logging.WARNING,
)
engine.run()
engine.calculate_equity_curve(calculate_net=False).plot(ax=ax, logy=True)
ax.set_ylabel('Cumulative returns');

# %%
print(f'Updated: {datetime.now(pytz.utc).strftime("%d-%b-%Y %H:%M")}')
# Out:
# Updated: 05-Jul-2026 23:17
