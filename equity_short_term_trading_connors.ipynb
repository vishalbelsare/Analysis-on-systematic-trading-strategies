# %% [markdown]
# # Short term trading strategies that work
#
# In this notebook, strategies mentioned in the book 'Short term trading strategies that work' from Larry Connors are investigated. This book mainly focuses on short-term mean-reversion strategies in the US equity market.

# %%
from datetime import datetime
import logging
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import pytz
import matplotlib.pyplot as plt
plt.style.use('bmh')

from vivace.backtest import (BacktestEngine, InstrumentDef,
                             Performance, signal, processing, rebase)
from vivace.backtest.engine import long_only_returns
from vivace.enums import Strategy, Weighting, PnLType

# %% [markdown]
# # Strategy 1
# If the following conditions are met, go long the equity market for 5 days.
# - It went down 3 days in a row
# - Price is above 200 day MA. Rationale is to go long when long-term trend is up and capture temporal pullback.

# %%
instruments = ['SPY', 'QQQ', '^GDAXI', '^N225']

# %%
def run_strat_1(instrument):
    engine = BacktestEngine(
        strategy=Strategy.DELTA_ONE.value,
        instrument=instrument,
        signal=signal.Pipeline([
            signal.ParallelSignal([
                signal.GreaterThanMA(lookback=200, shift=1),
                signal.ConsecutiveSign(n_consecutive=3, lookback_direction=-1, position=1)
            ], weighting='product', post_process=processing.CarryOver(5))
        ]),
        log_level=logging.WARNING,
    )
    engine.run()
    return engine


def run_backtests(backtest_func, instruments):
    result = []

    for name in instruments:
        instrument = InstrumentDef(name, pnl_type=PnLType.ADJCLOSE_TO_ADJCLOSE.value)
        strat_engine = backtest_func(instrument)
        strat_equity_curve = strat_engine.calculate_equity_curve(calculate_net=False).rename(f'Strategy ({name})')
        long_only = long_only_returns(instrument, strat_equity_curve.index[0], strat_equity_curve.index[-1])
        long_only_equity_curve = long_only.add(1).cumprod().rename(f'Long-only ({name})')

        result.append(
            pd.concat((long_only_equity_curve, strat_equity_curve), axis=1).pipe(rebase)
        )
    return result

# %%
strategy_1_result = run_backtests(run_strat_1, instruments)

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_1_result):
    result.plot(ax=ax, logy=True)

# %%
pd.concat([i.pipe(Performance).summary() for i in strategy_1_result], axis=1)
# Out:
#                  Long-only (SPY)  Strategy (SPY)  Long-only (QQQ)  \
# CAGR                    0.102877        0.049474         0.102795
# Annualised vol          0.185717        0.071515         0.269501
# Sharpe ratio            0.553945        0.691793         0.381427
# Max drawdown            0.551894        0.140756         0.829639
# Calmar ratio            0.186407        0.351488         0.123903
# Skewness               -0.011522       -0.775284         0.225613
# Kurtosis               11.827100       39.172067         7.128484
# Worst return           -0.109424       -0.072474        -0.119788
# Worst 1d return        -0.109424       -0.072474        -0.119788
# Worst 1w return        -0.197934       -0.081137        -0.246190
# Worst 1m return        -0.165187       -0.131988        -0.262053
#
#                  Strategy (QQQ)  Long-only (^GDAXI)  Strategy (^GDAXI)  \
# CAGR                   0.045778            0.083168           0.040501
# Annualised vol         0.098139            0.216776           0.081891
# Sharpe ratio           0.466467            0.383658           0.494574
# Max drawdown           0.265982            0.726848           0.233963
# Calmar ratio           0.172111            0.114423           0.173109
# Skewness               1.489714           -0.121715          -1.781806
# Kurtosis              68.670811            6.608840          65.244285
# Worst return          -0.086648           -0.131434          -0.131434
# Worst 1d return       -0.086648           -0.131434          -0.131434
# Worst 1w return       -0.246190           -0.216097          -0.128878
# Worst 1m return       -0.134703           -0.254222          -0.128878
#
#                  Long-only (^N225)  Strategy (^N225)
# CAGR                      0.066220          0.025652
# Annualised vol            0.203923          0.078035
# Sharpe ratio              0.324731          0.328719
# Max drawdown              0.818712          0.335098
# Calmar ratio              0.080883          0.076550
# Skewness                 -0.181917         -2.709517
# Kurtosis                  9.061039        102.846138
# Worst return             -0.149009         -0.149009
# Worst 1d return          -0.149009         -0.149009
# Worst 1w return          -0.243342         -0.127345
# Worst 1m return          -0.238269         -0.157023

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_1_result):
    result.tail(252 * 2).pipe(rebase).plot(ax=ax, logy=True)

# %% [markdown]
# # Strategy 2
#
# If the following conditions are met, go long the equity market for 5 days.
# - It the market made new 10-day lows
# - Price is above 200 day MA. Rationale is to go long when long-term trend is up and capture temporal pullback.

# %%
def run_strat_2(instrument):
    engine = BacktestEngine(
        strategy=Strategy.DELTA_ONE.value,
        instrument=instrument,
        signal=signal.Pipeline([
            signal.ParallelSignal([
                signal.GreaterThanMA(lookback=200, shift=1),
                signal.LocalMinimum(lookback=10, shift=1)
            ], weighting='product', post_process=processing.CarryOver(5))
        ]),
        log_level=logging.WARNING,
    )
    engine.run()
    return engine

# %%
strategy_2_result = run_backtests(run_strat_2, instruments)

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_2_result):
    result.plot(ax=ax, logy=True)

# %%
pd.concat([i.pipe(Performance).summary() for i in strategy_2_result], axis=1)
# Out:
#                  Long-only (SPY)  Strategy (SPY)  Long-only (QQQ)  \
# CAGR                    0.102877        0.061133         0.102795
# Annualised vol          0.185717        0.081768         0.269501
# Sharpe ratio            0.553945        0.747634         0.381427
# Max drawdown            0.551894        0.163105         0.829639
# Calmar ratio            0.186407        0.374804         0.123903
# Skewness               -0.011522       -0.561913         0.225613
# Kurtosis               11.827100       26.519725         7.128484
# Worst return           -0.109424       -0.072474        -0.119788
# Worst 1d return        -0.109424       -0.072474        -0.119788
# Worst 1w return        -0.197934       -0.081137        -0.246190
# Worst 1m return        -0.165187       -0.131988        -0.262053
#
#                  Strategy (QQQ)  Long-only (^GDAXI)  Strategy (^GDAXI)  \
# CAGR                   0.060334            0.083168           0.036238
# Annualised vol         0.112969            0.216776           0.088707
# Sharpe ratio           0.534081            0.383658           0.408507
# Max drawdown           0.282276            0.726848           0.256756
# Calmar ratio           0.213742            0.114423           0.141136
# Skewness               0.699041           -0.121715          -0.315613
# Kurtosis              44.029063            6.608840          16.691612
# Worst return          -0.086648           -0.131434          -0.058299
# Worst 1d return       -0.086648           -0.131434          -0.058299
# Worst 1w return       -0.246190           -0.216097          -0.087830
# Worst 1m return       -0.226028           -0.254222          -0.114044
#
#                  Long-only (^N225)  Strategy (^N225)
# CAGR                      0.066220          0.027654
# Annualised vol            0.203923          0.088997
# Sharpe ratio              0.324731          0.310732
# Max drawdown              0.818712          0.219014
# Calmar ratio              0.080883          0.126266
# Skewness                 -0.181917         -2.086660
# Kurtosis                  9.061039         74.160793
# Worst return             -0.149009         -0.149009
# Worst 1d return          -0.149009         -0.149009
# Worst 1w return          -0.243342         -0.127345
# Worst 1m return          -0.238269         -0.144419

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_2_result):
    result.tail(252 * 2).pipe(rebase).plot(ax=ax, logy=True)

# %% [markdown]
# # Strategy 3
#
# This strategy is the so-called "Double 7's strategy".

# %%
def run_strat_3(instrument):
    engine = BacktestEngine(
        strategy=Strategy.DELTA_ONE.value,
        instrument=instrument,
        signal=signal.Double7Connors(),
        log_level=logging.WARNING,
    )
    engine.run()
    return engine

# %%
strategy_3_result = run_backtests(run_strat_3, instruments)

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_3_result):
    result.plot(ax=ax, logy=True)

# %%
pd.concat([i.pipe(Performance).summary() for i in strategy_3_result], axis=1)
# Out:
#                  Long-only (SPY)  Strategy (SPY)  Long-only (QQQ)  \
# CAGR                    0.102877        0.073478         0.102795
# Annualised vol          0.185717        0.097622         0.269501
# Sharpe ratio            0.553945        0.752675         0.381427
# Max drawdown            0.551894        0.153224         0.829639
# Calmar ratio            0.186407        0.479544         0.123903
# Skewness               -0.011522       -0.294956         0.225613
# Kurtosis               11.827100       17.093155         7.128484
# Worst return           -0.109424       -0.072474        -0.119788
# Worst 1d return        -0.109424       -0.072474        -0.119788
# Worst 1w return        -0.197934       -0.111611        -0.246190
# Worst 1m return        -0.165187       -0.091371        -0.262053
#
#                  Strategy (QQQ)  Long-only (^GDAXI)  Strategy (^GDAXI)  \
# CAGR                   0.058479            0.083168           0.032144
# Annualised vol         0.141364            0.216776           0.116902
# Sharpe ratio           0.413674            0.383658           0.274970
# Max drawdown           0.480136            0.726848           0.382193
# Calmar ratio           0.121796            0.114423           0.084105
# Skewness               0.600101           -0.121715          -1.162277
# Kurtosis              31.281119            6.608840          35.596668
# Worst return          -0.089557           -0.131434          -0.131434
# Worst 1d return       -0.089557           -0.131434          -0.131434
# Worst 1w return       -0.246190           -0.216097          -0.200123
# Worst 1m return       -0.156000           -0.254222          -0.191921
#
#                  Long-only (^N225)  Strategy (^N225)
# CAGR                      0.066220          0.011534
# Annualised vol            0.203923          0.109817
# Sharpe ratio              0.324731          0.105029
# Max drawdown              0.818712          0.395910
# Calmar ratio              0.080883          0.029133
# Skewness                 -0.181917         -1.500733
# Kurtosis                  9.061039         49.039756
# Worst return             -0.149009         -0.149009
# Worst 1d return          -0.149009         -0.149009
# Worst 1w return          -0.243342         -0.159939
# Worst 1m return          -0.238269         -0.167306

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_3_result):
    result.tail(252 * 2).pipe(rebase).plot(ax=ax, logy=True)

# %% [markdown]
# # Strategy 4
# Month-end strategy which goes long when the following conditions are met:
# - n days before month-end
#     - (optional) only do so when the previous day is down
# - The price is above 200 day MA

# %%
def run_strat_4(instrument):
    engine = BacktestEngine(
        strategy=Strategy.DELTA_ONE.value,
        instrument=instrument,
        signal=signal.Pipeline([
            signal.ParallelSignal([
                signal.GreaterThanMA(lookback=200, shift=1),
                signal.MonthEndLong(n_before=5, n_after=0, is_prev_neg=True),
            ], weighting='product', post_process=processing.CarryOver(5))
        ]),
        log_level=logging.WARNING,
    )
    engine.run()
    return engine

# %%
strategy_4_result = run_backtests(run_strat_4, instruments)

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_4_result):
    result.plot(ax=ax, logy=True)

# %%
pd.concat([i.pipe(Performance).summary() for i in strategy_4_result], axis=1)
# Out:
#                  Long-only (SPY)  Strategy (SPY)  Long-only (QQQ)  \
# CAGR                    0.102877        0.036352         0.102795
# Annualised vol          0.185717        0.060797         0.269501
# Sharpe ratio            0.553945        0.597932         0.381427
# Max drawdown            0.551894        0.111611         0.829639
# Calmar ratio            0.186407        0.325705         0.123903
# Skewness               -0.011522       -0.772800         0.225613
# Kurtosis               11.827100       46.676117         7.128484
# Worst return           -0.109424       -0.072474        -0.119788
# Worst 1d return        -0.109424       -0.072474        -0.119788
# Worst 1w return        -0.197934       -0.111611        -0.246190
# Worst 1m return        -0.165187       -0.077785        -0.262053
#
#                  Strategy (QQQ)  Long-only (^GDAXI)  Strategy (^GDAXI)  \
# CAGR                   0.042486            0.083168           0.023792
# Annualised vol         0.080524            0.216776           0.066842
# Sharpe ratio           0.527617            0.383658           0.355950
# Max drawdown           0.140946            0.726848           0.238856
# Calmar ratio           0.301435            0.114423           0.099610
# Skewness               0.434445           -0.121715          -0.411827
# Kurtosis              38.994808            6.608840          28.309682
# Worst return          -0.057516           -0.131434          -0.049530
# Worst 1d return       -0.057516           -0.131434          -0.049530
# Worst 1w return       -0.106267           -0.216097          -0.124379
# Worst 1m return       -0.084241           -0.254222          -0.124379
#
#                  Long-only (^N225)  Strategy (^N225)
# CAGR                      0.066220          0.019475
# Annualised vol            0.203923          0.063341
# Sharpe ratio              0.324731          0.307455
# Max drawdown              0.818712          0.428543
# Calmar ratio              0.080883          0.045444
# Skewness                 -0.181917         -2.464044
# Kurtosis                  9.061039        148.922777
# Worst return             -0.149009         -0.123958
# Worst 1d return          -0.149009         -0.123958
# Worst 1w return          -0.243342         -0.127345
# Worst 1m return          -0.238269         -0.123825

# %%
fig, axes = plt.subplots(1, len(instruments), figsize=(14, 5), sharey=True)

for ax, result in zip(axes, strategy_4_result):
    result.tail(252 * 2).pipe(rebase).plot(ax=ax, logy=True)

# %% [markdown]
# # Reference
# - Connors, L.A. and Alvarez, C., 2009. Short Term Trading Strategies that Work: A Quantified Guide to Trading Stocks and ETFs. TradingMarkets Publishing Group.

# %%
print(f'Updated: {datetime.now(pytz.utc):%d-%b-%Y %H:%M}')
# Out:
# Updated: 09-Jul-2026 00:33
